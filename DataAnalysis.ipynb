# %%
import csv

# %%
filename = '/Users/saulcoops/Documents/Uni/Year_3/individual-project/saulcooperman-fyp/runs/2024-03-25_21-20-41/my_data.csv'  # Path to your CSV file

# Initialize an empty list to hold the data
data = []

# Open the CSV file and read the contents
with open(filename, mode='r', newline='') as file:
    reader = csv.reader(file)
    for row in reader:
        # Each row is a list; you can convert values or leave them as strings
        data.append(row)

# Now, data contains all the rows of the CSV file as lists
print(data)
# Out:
# [['[ 1.00000000e+00  9.78723404e-01  9.57446809e-01  9.36170213e-01\n  9.14893617e-01  8.93617021e-01  8.72340426e-01  8.51063830e-01\n  8.29787234e-01  8.08510638e-01  7.87234043e-01  7.65957447e-01\n  7.44680851e-01  7.23404255e-01  7.02127660e-01  6.80851064e-01\n  6.59574468e-01  6.38297872e-01  6.17021277e-01  5.95744681e-01\n  5.74468085e-01  5.53191489e-01  5.31914894e-01  5.10638298e-01\n  4.89361702e-01  4.68085106e-01  4.46808511e-01  4.25531915e-01\n  4.04255319e-01  3.82978723e-01  3.61702128e-01  3.40425532e-01\n  3.19148936e-01  2.97872340e-01  2.76595745e-01  2.55319149e-01\n  2.34042553e-01  2.12765957e-01  1.91489362e-01  1.70212766e-01\n  1.48936170e-01  1.27659574e-01  1.06382979e-01  8.51063830e-02\n  6.38297872e-02  4.25531915e-02  2.12765957e-02 -7.70732219e-16]', '[-3.74286741e-03 -3.07289656e-03 -2.46492329e-03 -1.91703087e-03\n -1.42679537e-03 -9.91398051e-04 -6.07725877e-04 -2.72460895e-04\n  1.78410489e-05  2.66586849e-04  4.77275793e-04  6.53353838e-04\n  
# ...
